# %%
import pandas as pd

# %%
df=pd.read_csv('C:\\Users\\USER\\Desktop\\Boston.csv')
df
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio   black  lstat  medv
# ...

# %%
df.head()
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7
# 3  222     18.7  394.63   2.94  33.4
# 4  222     18.7  396.90   5.33  36.2

# %%
df.describe()
# Out:
#        Unnamed: 0        crim          zn       indus        chas         nox  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   253.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      1.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    127.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    253.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    379.750000    3.677082   12.500000   18.100000    0.000000    0.624000
# max    506.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# ...

# %%
df.tail()
# Out:
#      Unnamed: 0     crim   zn  indus  chas    nox     rm   age     dis  rad  \
# 501         502  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio   black  lstat  medv
# 501  273     21.0  391.99   9.67  22.4
# 502  273     21.0  396.90   9.08  20.6
# 503  273     21.0  396.90   5.64  23.9
# 504  273     21.0  393.45   6.48  22.0
# 505  273     21.0  396.90   7.88  11.9

# %%
df.isna()
# Out:
#      Unnamed: 0   crim     zn  indus   chas    nox     rm    age    dis  \
# 0         False  False  False  False  False  False  False  False  False
# 1         False  False  False  False  False  False  False  False  False
# 2         False  False  False  False  False  False  False  False  False
# 3         False  False  False  False  False  False  False  False  False
# 4         False  False  False  False  False  False  False  False  False
# ..          ...    ...    ...    ...    ...    ...    ...    ...    ...
# 501       False  False  False  False  False  False  False  False  False
# 502       False  False  False  False  False  False  False  False  False
# 503       False  False  False  False  False  False  False  False  False
# 504       False  False  False  False  False  False  False  False  False
# 505       False  False  False  False  False  False  False  False  False
#
#        rad    tax  ptratio  black  lstat   medv
# 0    False  False    False  False  False  False
# ...

# %%
y=df[['medv']]

# %%
x=df[['crim']]

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
y_test.head()
# Out:
#      medv
# 427  10.9
# 101  26.5
# 81   23.9
# 482  25.0
# 189  34.9

# %%
y_pred[0:5]
# Out:
# array([[ 4.90078783],
#        [24.37166717],
#        [24.40781118],
#        [21.45896776],
#        [24.38754564]])

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 70.27466495980659

# %%
x=df[['lstat']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-210803e61f89> in <module>
# ----> 1 x=df[['lstat']]
#
# NameError: name 'df' is not defined

# %%
#linearRegression model implimentation when we have dependent variable as medv (under variable y) and independent variables as crim and lstat 
import pandas as pd

# %%
boston=pd.read_csv('C:\\Users\\USER\\Desktop\\Boston.csv')

# %%
boston
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio   black  lstat  medv
# ...

# %%
x=boston[['crim']]

# %%
y=boston[['medv']]

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
y_test.head()
# Out:
#      medv
# 139  17.8
# 98   43.8
# 110  21.7
# 212  22.4
# 249  26.2

# %%
y_pred[0:5]
# Out:
# array([[23.8847875 ],
#        [24.0579745 ],
#        [24.04821928],
#        [24.00731922],
#        [24.01722418]])

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 57.70716809271621

# %%
x=boston[['lstat']]

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_test.head()
# Out:
#      medv
# 139  17.8
# 98   43.8
# 110  21.7
# 212  22.4
# 249  26.2

# %%
y_pred=lr.predict(x_test)

# %%
y_pred[0:5]
# Out:
# array([[23.8847875 ],
#        [24.0579745 ],
#        [24.04821928],
#        [24.00731922],
#        [24.01722418]])

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 57.70716809271621

# %%
import pandas as pd

# %%
boston=pd.read_csv('C:\\Users\\USER\\Desktop\\Boston.csv')

# %%
boston.head()
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7
# 3  222     18.7  394.63   2.94  33.4
# 4  222     18.7  396.90   5.33  36.2

# %%
#logistic regression is used in classification whenever we have catagorical variables
import pandas as pd

# %%
customer=pd.read_csv('C:\\Users\\USER\\Desktop\\Customer_Churn.csv')

# %%
customer
# Out:
#                 Names  Age  Total_Purchase  Account_Manager  Years  Num_Sites  \
# 0    Cameron Williams   42        11066.80                0   7.22          8
# 1       Kevin Mueller   41        11916.22                0   6.50         11
# 2         Eric Lozano   38        12884.75                0   6.67         12
# 3       Phillip White   42         8010.76                0   6.71         10
# 4      Cynthia Norton   37         9191.58                0   5.56          9
# ..                ...  ...             ...              ...    ...        ...
# 895       Paul Miller   42        12800.82                1   3.62          8
# 896    Natalie Hodges   52         9893.92                0   6.91          7
# 897         Ana Smith   45        12056.18                0   5.46          4
# 898    Justin Leonard   51         6517.93                1   5.47         10
# 899   Joseph Williams   39         9315.60                1   5.02         10
#
# ...

# %%
x=customer[['Names']]
